# %%
import numpy as np
import matplotlib.pyplot as plt



t = np.genfromtxt("triangular_perc_3.txt")
t_t = np.genfromtxt("triangular_perc_testing_3.txt")

k = 39
n=1

plt.plot(t[k*n:k*(n+1), 0], t[k*n:k*(n+1), 1], "ro")
plt.plot(t_t[:, 0], t_t[:, 1], "bx")

# %%
t = np.genfromtxt("triangular_perc_2.txt")

k = 39
n=1

plt.plot(t[k*n:k*(n+1), 0], t[k*n:k*(n+1), 1], "ro")

# %%
n = 1

a = t[k*n:k*(n+1), 1]
c = len(a)-1
b = np.ones(c)
b[:] = a[:-1] - a[1:]
plt.plot(np.arange(0, c), b)
print(a, b)
# Out:
# [0.705705   0.448824   0.00503713 0.00443069 0.00456683 0.00490099
#  0.00475248 0.00539604 0.00490099 0.00491337 0.0049505  0.00454208
#  0.0047401  0.00446782 0.0050495  0.00517327 0.00490099 0.00464109
#  0.00498762 0.0044802  0.00488861 0.00439356 0.00470297 0.00455446
#  0.00450495 0.00467822 0.00488861 0.00466584] [ 2.5688100e-01  4.4378687e-01  6.0644000e-04 -1.3614000e-04
#  -3.3416000e-04  1.4851000e-04 -6.4356000e-04  4.9505000e-04
#  -1.2380000e-05 -3.7130000e-05  4.0842000e-04 -1.9802000e-04
#   2.7228000e-04 -5.8168000e-04 -1.2377000e-04  2.7228000e-04
#   2.5990000e-04 -3.4653000e-04  5.0742000e-04 -4.0841000e-04
#   4.9505000e-04 -3.0941000e-04  1.4851000e-04  4.9510000e-05
#  -1.7327000e-04 -2.1039000e-04  2.2277000e-04]

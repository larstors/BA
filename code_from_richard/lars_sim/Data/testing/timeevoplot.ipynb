# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as opt
import time
import random as rn
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
import matplotlib.patches as mpl_patches
from matplotlib import rcParams
from cmath import nan

plt.rcParams.update({'font.size': 20})

# %%
# ############################### SQUARE DATA #################################
data_1_square = np.genfromtxt("square_number_alpha0.100_phi0.47_L100_1.txt", delimiter=" ")
data_2_square = np.genfromtxt("square_number_alpha0.010_phi0.47_L100_1.txt", delimiter=" ")
data_7_square = np.genfromtxt("square_number_alpha0.001_phi0.47_L100_1.txt", delimiter=" ")
data_10_square = np.genfromtxt("square_number_alpha0.000_phi0.47_L100_1.txt", delimiter=" ")

data_3_square = np.genfromtxt("square_number_alpha0.100_phi0.55_L100_2.txt", delimiter=" ")
data_4_square = np.genfromtxt("square_number_alpha0.010_phi0.55_L100_2.txt", delimiter=" ")
data_8_square = np.genfromtxt("square_number_alpha0.001_phi0.55_L100_2.txt", delimiter=" ")
data_11_square = np.genfromtxt("square_number_alpha0.000_phi0.55_L100_2.txt", delimiter=" ")

data_5_square = np.genfromtxt("square_number_alpha0.100_phi0.58_L100_3.txt", delimiter=" ")
data_6_square = np.genfromtxt("square_number_alpha0.010_phi0.58_L100_3.txt", delimiter=" ")
data_9_square = np.genfromtxt("square_number_alpha0.001_phi0.58_L100_3.txt", delimiter=" ")
data_12_square = np.genfromtxt("square_number_alpha0.000_phi0.58_L100_3.txt", delimiter=" ")


print(np.shape(data_1_square))
# Out:
# (1159, 3)

# %%
# ############################### TRI DATA #################################
data_1_tri = np.genfromtxt("tri_number_alpha0.100_phi0.40_L100_1.txt", delimiter=" ")
data_2_tri = np.genfromtxt("tri_number_alpha0.010_phi0.40_L100_1.txt", delimiter=" ")
data_7_tri = np.genfromtxt("tri_number_alpha0.001_phi0.40_L100_1.txt", delimiter=" ")
data_10_tri = np.genfromtxt("tri_number_alpha0.000_phi0.40_L100_1.txt", delimiter=" ")

data_3_tri = np.genfromtxt("tri_number_alpha0.100_phi0.45_L100_2.txt", delimiter=" ")
data_4_tri = np.genfromtxt("tri_number_alpha0.010_phi0.45_L100_2.txt", delimiter=" ")
data_8_tri = np.genfromtxt("tri_number_alpha0.001_phi0.45_L100_2.txt", delimiter=" ")
data_11_tri = np.genfromtxt("tri_number_alpha0.000_phi0.45_L100_2.txt", delimiter=" ")

data_5_tri = np.genfromtxt("tri_number_alpha0.100_phi0.47_L100_3.txt", delimiter=" ")
data_6_tri = np.genfromtxt("tri_number_alpha0.010_phi0.47_L100_3.txt", delimiter=" ")
data_9_tri = np.genfromtxt("tri_number_alpha0.001_phi0.47_L100_3.txt", delimiter=" ")
data_12_tri = np.genfromtxt("tri_number_alpha0.000_phi0.47_L100_3.txt", delimiter=" ")

# %%
# ############################### HEX DATA #################################
data_1_hex = np.genfromtxt("hex_number_alpha0.100_phi1.10_L100_1.txt", delimiter=" ")
data_2_hex = np.genfromtxt("hex_number_alpha0.010_phi1.10_L100_1.txt", delimiter=" ")
data_7_hex = np.genfromtxt("hex_number_alpha0.001_phi1.10_L100_1.txt", delimiter=" ")
data_10_hex = np.genfromtxt("hex_number_alpha0.000_phi1.10_L100_1.txt", delimiter=" ")

data_3_hex = np.genfromtxt("hex_number_alpha0.100_phi1.32_L100_2.txt", delimiter=" ")
data_4_hex = np.genfromtxt("hex_number_alpha0.010_phi1.32_L100_2.txt", delimiter=" ")
data_8_hex = np.genfromtxt("hex_number_alpha0.001_phi1.32_L100_2.txt", delimiter=" ")
data_11_hex = np.genfromtxt("hex_number_alpha0.000_phi1.32_L100_2.txt", delimiter=" ")

data_5_hex = np.genfromtxt("hex_number_alpha0.100_phi1.41_L100_3.txt", delimiter=" ")
data_6_hex = np.genfromtxt("hex_number_alpha0.010_phi1.41_L100_3.txt", delimiter=" ")
data_9_hex = np.genfromtxt("hex_number_alpha0.001_phi1.41_L100_3.txt", delimiter=" ")
data_12_hex = np.genfromtxt("hex_number_alpha0.000_phi1.41_L100_3.txt", delimiter=" ")

# %%
# Square

# ###################################### FIG 1 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_1_square[1:-2, 0], data_1_square[1:-2, 1], label=r"$\alpha=0.1$")
ax[0].plot(data_2_square[1:-2, 0], data_2_square[1:-2, 1], label=r"$\alpha=0.01$")
ax[0].plot(data_7_square[1:-2, 0], data_7_square[1:-2, 1], label=r"$\alpha=0.001$")
ax[0].plot(data_10_square[1:-2, 0], data_10_square[1:-2, 1], label=r"$\alpha=0$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_1_square[1:-2, 0], data_1_square[1:-2, 2], label=r"$\alpha=0.1$")
ax[1].plot(data_2_square[1:-2, 0], data_2_square[1:-2, 2], label=r"$\alpha=0.01$")
ax[1].plot(data_7_square[1:-2, 0], data_7_square[1:-2, 2], label=r"$\alpha=0.001$")
ax[1].plot(data_10_square[1:-2, 0], data_10_square[1:-2, 2], label=r"$\alpha=0$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("square_1.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 2 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_3_square[1:-2, 0], data_3_square[1:-2, 1], label=r"$\alpha=0.1$")
ax[0].plot(data_4_square[1:-2, 0], data_4_square[1:-2, 1], label=r"$\alpha=0.01$")
ax[0].plot(data_8_square[1:-2, 0], data_8_square[1:-2, 1], label=r"$\alpha=0.001$")
ax[0].plot(data_11_square[1:-2, 0], data_11_square[1:-2, 1], label=r"$\alpha=0$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_3_square[1:-2, 0], data_3_square[1:-2, 2], label=r"$\alpha=0.1$")
ax[1].plot(data_4_square[1:-2, 0], data_4_square[1:-2, 2], label=r"$\alpha=0.01$")
ax[1].plot(data_8_square[1:-2, 0], data_8_square[1:-2, 2], label=r"$\alpha=0.001$")
ax[1].plot(data_11_square[1:-2, 0], data_11_square[1:-2, 2], label=r"$\alpha=0$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("square_2.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 3 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_5_square[1:-2, 0], data_5_square[1:-2, 1], label=r"$\alpha=0.1$")
ax[0].plot(data_6_square[1:-2, 0], data_6_square[1:-2, 1], label=r"$\alpha=0.01$")
ax[0].plot(data_9_square[1:-2, 0], data_9_square[1:-2, 1], label=r"$\alpha=0.001$")
ax[0].plot(data_12_square[1:-2, 0], data_12_square[1:-2, 1], label=r"$\alpha=0$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_5_square[1:-2, 0], data_5_square[1:-2, 2], label=r"$\alpha=0.1$")
ax[1].plot(data_6_square[1:-2, 0], data_6_square[1:-2, 2], label=r"$\alpha=0.01$")
ax[1].plot(data_9_square[1:-2, 0], data_9_square[1:-2, 2], label=r"$\alpha=0.001$")
ax[1].plot(data_12_square[1:-2, 0], data_12_square[1:-2, 2], label=r"$\alpha=0$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("square_3.pdf", dpi=200, bbox_inches='tight')

# %%
# comparison of same alpha different n

# ###################################### FIG 1 ################################################
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_1_square[1:-2, 0], data_1_square[1:-2, 1], label=r"$n_\mathrm{max}=1$")
ax[0].plot(data_3_square[1:-2, 0], data_3_square[1:-2, 1], label=r"$n_\mathrm{max}=2$")
ax[0].plot(data_5_square[1:-2, 0], data_5_square[1:-2, 1], label=r"$n_\mathrm{max}=3$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_1_square[1:-2, 0], data_1_square[1:-2, 2], label=r"$n_\mathrm{max}=1$")
ax[1].plot(data_3_square[1:-2, 0], data_3_square[1:-2, 2], label=r"$n_\mathrm{max}=2$")
ax[1].plot(data_5_square[1:-2, 0], data_5_square[1:-2, 2], label=r"$n_\mathrm{max}=3$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("square_comp_n_alpha_0.1.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 2 ################################################
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_2_square[1:-2, 0], data_2_square[1:-2, 1], label=r"$n_\mathrm{max}=1$")
ax[0].plot(data_4_square[1:-2, 0], data_4_square[1:-2, 1], label=r"$n_\mathrm{max}=2$")
ax[0].plot(data_6_square[1:-2, 0], data_6_square[1:-2, 1], label=r"$n_\mathrm{max}=3$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_2_square[1:-2, 0], data_2_square[1:-2, 2], label=r"$n_\mathrm{max}=1$")
ax[1].plot(data_4_square[1:-2, 0], data_4_square[1:-2, 2], label=r"$n_\mathrm{max}=2$")
ax[1].plot(data_6_square[1:-2, 0], data_6_square[1:-2, 2], label=r"$n_\mathrm{max}=3$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("square_comp_n_alpha_0.01.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 3 ################################################
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_7_square[1:-2, 0], data_7_square[1:-2, 1], label=r"$n_\mathrm{max}=1$")
ax[0].plot(data_8_square[1:-2, 0], data_8_square[1:-2, 1], label=r"$n_\mathrm{max}=2$")
ax[0].plot(data_9_square[1:-2, 0], data_9_square[1:-2, 1], label=r"$n_\mathrm{max}=3$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_7_square[1:-2, 0], data_7_square[1:-2, 2], label=r"$n_\mathrm{max}=1$")
ax[1].plot(data_8_square[1:-2, 0], data_8_square[1:-2, 2], label=r"$n_\mathrm{max}=2$")
ax[1].plot(data_9_square[1:-2, 0], data_9_square[1:-2, 2], label=r"$n_\mathrm{max}=3$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("square_comp_n_alpha_0.001.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 4 ################################################
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_10_square[1:-2, 0], data_10_square[1:-2, 1], label=r"$n_\mathrm{max}=1$")
ax[0].plot(data_11_square[1:-2, 0], data_11_square[1:-2, 1], label=r"$n_\mathrm{max}=2$")
ax[0].plot(data_12_square[1:-2, 0], data_12_square[1:-2, 1], label=r"$n_\mathrm{max}=3$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_10_square[1:-2, 0], data_10_square[1:-2, 2], label=r"$n_\mathrm{max}=1$")
ax[1].plot(data_11_square[1:-2, 0], data_11_square[1:-2, 2], label=r"$n_\mathrm{max}=2$")
ax[1].plot(data_12_square[1:-2, 0], data_12_square[1:-2, 2], label=r"$n_\mathrm{max}=3$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("square_comp_n_alpha_0.pdf", dpi=200, bbox_inches='tight')

# %%
# Tri

# ###################################### FIG 1 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_1_tri[1:-2, 0], data_1_tri[1:-2, 1], label=r"$\alpha=0.1$")
ax[0].plot(data_2_tri[1:-2, 0], data_2_tri[1:-2, 1], label=r"$\alpha=0.01$")
ax[0].plot(data_7_tri[1:-2, 0], data_7_tri[1:-2, 1], label=r"$\alpha=0.001$")
ax[0].plot(data_10_tri[1:-2, 0], data_10_tri[1:-2, 1], label=r"$\alpha=0$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_1_tri[1:-2, 0], data_1_tri[1:-2, 2], label=r"$\alpha=0.1$")
ax[1].plot(data_2_tri[1:-2, 0], data_2_tri[1:-2, 2], label=r"$\alpha=0.01$")
ax[1].plot(data_7_tri[1:-2, 0], data_7_tri[1:-2, 2], label=r"$\alpha=0.001$")
ax[1].plot(data_10_tri[1:-2, 0], data_10_tri[1:-2, 2], label=r"$\alpha=0$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("tri_1.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 2 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_3_tri[1:-2, 0], data_3_tri[1:-2, 1], label=r"$\alpha=0.1$")
ax[0].plot(data_4_tri[1:-2, 0], data_4_tri[1:-2, 1], label=r"$\alpha=0.01$")
ax[0].plot(data_8_tri[1:-2, 0], data_8_tri[1:-2, 1], label=r"$\alpha=0.001$")
ax[0].plot(data_11_tri[1:-2, 0], data_11_tri[1:-2, 1], label=r"$\alpha=0$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_3_tri[1:-2, 0], data_3_tri[1:-2, 2], label=r"$\alpha=0.1$")
ax[1].plot(data_4_tri[1:-2, 0], data_4_tri[1:-2, 2], label=r"$\alpha=0.01$")
ax[1].plot(data_8_tri[1:-2, 0], data_8_tri[1:-2, 2], label=r"$\alpha=0.001$")
ax[1].plot(data_11_tri[1:-2, 0], data_11_tri[1:-2, 2], label=r"$\alpha=0$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("tri_2.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 3 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_5_tri[1:-2, 0], data_5_tri[1:-2, 1], label=r"$\alpha=0.1$")
ax[0].plot(data_6_tri[1:-2, 0], data_6_tri[1:-2, 1], label=r"$\alpha=0.01$")
ax[0].plot(data_9_tri[1:-2, 0], data_9_tri[1:-2, 1], label=r"$\alpha=0.001$")
ax[0].plot(data_12_tri[1:-2, 0], data_12_tri[1:-2, 1], label=r"$\alpha=0$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_5_tri[1:-2, 0], data_5_tri[1:-2, 2], label=r"$\alpha=0.1$")
ax[1].plot(data_6_tri[1:-2, 0], data_6_tri[1:-2, 2], label=r"$\alpha=0.01$")
ax[1].plot(data_9_tri[1:-2, 0], data_9_tri[1:-2, 2], label=r"$\alpha=0.001$")
ax[1].plot(data_12_tri[1:-2, 0], data_12_tri[1:-2, 2], label=r"$\alpha=0$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("tri_3.pdf", dpi=200, bbox_inches='tight')

# comparison of same alpha different n
# ###################################### FIG 1 ################################################
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_1_tri[1:-2, 0], data_1_tri[1:-2, 1], label=r"$n_\mathrm{max}=1$")
ax[0].plot(data_3_tri[1:-2, 0], data_3_tri[1:-2, 1], label=r"$n_\mathrm{max}=2$")
ax[0].plot(data_5_tri[1:-2, 0], data_5_tri[1:-2, 1], label=r"$n_\mathrm{max}=3$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_1_tri[1:-2, 0], data_1_tri[1:-2, 2], label=r"$n_\mathrm{max}=1$")
ax[1].plot(data_3_tri[1:-2, 0], data_3_tri[1:-2, 2], label=r"$n_\mathrm{max}=2$")
ax[1].plot(data_5_tri[1:-2, 0], data_5_tri[1:-2, 2], label=r"$n_\mathrm{max}=3$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("tri_comp_n_alpha_0.1.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 2 ################################################
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_2_tri[1:-2, 0], data_2_tri[1:-2, 1], label=r"$n_\mathrm{max}=1$")
ax[0].plot(data_4_tri[1:-2, 0], data_4_tri[1:-2, 1], label=r"$n_\mathrm{max}=2$")
ax[0].plot(data_6_tri[1:-2, 0], data_6_tri[1:-2, 1], label=r"$n_\mathrm{max}=3$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_2_tri[1:-2, 0], data_2_tri[1:-2, 2], label=r"$n_\mathrm{max}=1$")
ax[1].plot(data_4_tri[1:-2, 0], data_4_tri[1:-2, 2], label=r"$n_\mathrm{max}=2$")
ax[1].plot(data_6_tri[1:-2, 0], data_6_tri[1:-2, 2], label=r"$n_\mathrm{max}=3$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("tri_comp_n_alpha_0.01.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 3 ################################################
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_7_tri[1:-2, 0], data_7_tri[1:-2, 1], label=r"$n_\mathrm{max}=1$")
ax[0].plot(data_8_tri[1:-2, 0], data_8_tri[1:-2, 1], label=r"$n_\mathrm{max}=2$")
ax[0].plot(data_9_tri[1:-2, 0], data_9_tri[1:-2, 1], label=r"$n_\mathrm{max}=3$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_7_tri[1:-2, 0], data_7_tri[1:-2, 2], label=r"$n_\mathrm{max}=1$")
ax[1].plot(data_8_tri[1:-2, 0], data_8_tri[1:-2, 2], label=r"$n_\mathrm{max}=2$")
ax[1].plot(data_9_tri[1:-2, 0], data_9_tri[1:-2, 2], label=r"$n_\mathrm{max}=3$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("tri_comp_n_alpha_0.001.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 4 ################################################
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_10_tri[1:-2, 0], data_10_tri[1:-2, 1], label=r"$n_\mathrm{max}=1$")
ax[0].plot(data_11_tri[1:-2, 0], data_11_tri[1:-2, 1], label=r"$n_\mathrm{max}=2$")
ax[0].plot(data_12_tri[1:-2, 0], data_12_tri[1:-2, 1], label=r"$n_\mathrm{max}=3$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_10_tri[1:-2, 0], data_10_tri[1:-2, 2], label=r"$n_\mathrm{max}=1$")
ax[1].plot(data_11_tri[1:-2, 0], data_11_tri[1:-2, 2], label=r"$n_\mathrm{max}=2$")
ax[1].plot(data_12_tri[1:-2, 0], data_12_tri[1:-2, 2], label=r"$n_\mathrm{max}=3$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("tri_comp_n_alpha_0.pdf", dpi=200, bbox_inches='tight')

# %%
# Hex
# ###################################### FIG 1 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_1_hex[1:-2, 0], data_1_hex[1:-2, 1], label=r"$\alpha=0.1$")
ax[0].plot(data_2_hex[1:-2, 0], data_2_hex[1:-2, 1], label=r"$\alpha=0.01$")
ax[0].plot(data_7_hex[1:-2, 0], data_7_hex[1:-2, 1], label=r"$\alpha=0.001$")
ax[0].plot(data_10_hex[1:-2, 0], data_10_hex[1:-2, 1], label=r"$\alpha=0$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_1_hex[1:-2, 0], data_1_hex[1:-2, 2], label=r"$\alpha=0.1$")
ax[1].plot(data_2_hex[1:-2, 0], data_2_hex[1:-2, 2], label=r"$\alpha=0.01$")
ax[1].plot(data_7_hex[1:-2, 0], data_7_hex[1:-2, 2], label=r"$\alpha=0.001$")
ax[1].plot(data_10_hex[1:-2, 0], data_10_hex[1:-2, 2], label=r"$\alpha=0$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("hex_1.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 2 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_3_hex[1:-2, 0], data_3_hex[1:-2, 1], label=r"$\alpha=0.1$")
ax[0].plot(data_4_hex[1:-2, 0], data_4_hex[1:-2, 1], label=r"$\alpha=0.01$")
ax[0].plot(data_8_hex[1:-2, 0], data_8_hex[1:-2, 1], label=r"$\alpha=0.001$")
ax[0].plot(data_11_hex[1:-2, 0], data_11_hex[1:-2, 1], label=r"$\alpha=0$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")


ax[1].plot(data_3_hex[1:-2, 0], data_3_hex[1:-2, 2], label=r"$\alpha=0.1$")
ax[1].plot(data_4_hex[1:-2, 0], data_4_hex[1:-2, 2], label=r"$\alpha=0.01$")
ax[1].plot(data_8_hex[1:-2, 0], data_8_hex[1:-2, 2], label=r"$\alpha=0.001$")
ax[1].plot(data_11_hex[1:-2, 0], data_11_hex[1:-2, 2], label=r"$\alpha=0$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("hex_2.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 3 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_5_hex[1:-2, 0], data_5_hex[1:-2, 1], label=r"$\alpha=0.1$")
ax[0].plot(data_6_hex[1:-2, 0], data_6_hex[1:-2, 1], label=r"$\alpha=0.01$")
ax[0].plot(data_9_hex[1:-2, 0], data_9_hex[1:-2, 1], label=r"$\alpha=0.001$")
ax[0].plot(data_12_hex[1:-2, 0], data_12_hex[1:-2, 1], label=r"$\alpha=0$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_5_hex[1:-2, 0], data_5_hex[1:-2, 2], label=r"$\alpha=0.1$")
ax[1].plot(data_6_hex[1:-2, 0], data_6_hex[1:-2, 2], label=r"$\alpha=0.01$")
ax[1].plot(data_9_hex[1:-2, 0], data_9_hex[1:-2, 2], label=r"$\alpha=0.001$")
ax[1].plot(data_12_hex[1:-2, 0], data_12_hex[1:-2, 2], label=r"$\alpha=0$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("hex_3.pdf", dpi=200, bbox_inches='tight')

# n comparison
# ###################################### FIG 1 ################################################
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_1_hex[1:-2, 0], data_1_hex[1:-2, 1], label=r"$n_\mathrm{max}=1$")
ax[0].plot(data_3_hex[1:-2, 0], data_3_hex[1:-2, 1], label=r"$n_\mathrm{max}=2$")
ax[0].plot(data_5_hex[1:-2, 0], data_5_hex[1:-2, 1], label=r"$n_\mathrm{max}=3$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_1_hex[1:-2, 0], data_1_hex[1:-2, 2], label=r"$n_\mathrm{max}=1$")
ax[1].plot(data_3_hex[1:-2, 0], data_3_hex[1:-2, 2], label=r"$n_\mathrm{max}=2$")
ax[1].plot(data_5_hex[1:-2, 0], data_5_hex[1:-2, 2], label=r"$n_\mathrm{max}=3$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("hex_comp_n_alpha_0.1.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 2 ################################################
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_2_hex[1:-2, 0], data_2_hex[1:-2, 1], label=r"$n_\mathrm{max}=1$")
ax[0].plot(data_4_hex[1:-2, 0], data_4_hex[1:-2, 1], label=r"$n_\mathrm{max}=2$")
ax[0].plot(data_6_hex[1:-2, 0], data_6_hex[1:-2, 1], label=r"$n_\mathrm{max}=3$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_2_hex[1:-2, 0], data_2_hex[1:-2, 2], label=r"$n_\mathrm{max}=1$")
ax[1].plot(data_4_hex[1:-2, 0], data_4_hex[1:-2, 2], label=r"$n_\mathrm{max}=2$")
ax[1].plot(data_6_hex[1:-2, 0], data_6_hex[1:-2, 2], label=r"$n_\mathrm{max}=3$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("hex_comp_n_alpha_0.01.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 3 ################################################
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_7_hex[1:-2, 0], data_7_hex[1:-2, 1], label=r"$n_\mathrm{max}=1$")
ax[0].plot(data_8_hex[1:-2, 0], data_8_hex[1:-2, 1], label=r"$n_\mathrm{max}=2$")
ax[0].plot(data_9_hex[1:-2, 0], data_9_hex[1:-2, 1], label=r"$n_\mathrm{max}=3$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_7_hex[1:-2, 0], data_7_hex[1:-2, 2], label=r"$n_\mathrm{max}=1$")
ax[1].plot(data_8_hex[1:-2, 0], data_8_hex[1:-2, 2], label=r"$n_\mathrm{max}=2$")
ax[1].plot(data_9_hex[1:-2, 0], data_9_hex[1:-2, 2], label=r"$n_\mathrm{max}=3$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("hex_comp_n_alpha_0.001.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 4 ################################################
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_10_hex[1:-2, 0], data_10_hex[1:-2, 1], label=r"$n_\mathrm{max}=1$")
ax[0].plot(data_11_hex[1:-2, 0], data_11_hex[1:-2, 1], label=r"$n_\mathrm{max}=2$")
ax[0].plot(data_12_hex[1:-2, 0], data_12_hex[1:-2, 1], label=r"$n_\mathrm{max}=3$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_10_hex[1:-2, 0], data_10_hex[1:-2, 2], label=r"$n_\mathrm{max}=1$")
ax[1].plot(data_11_hex[1:-2, 0], data_11_hex[1:-2, 2], label=r"$n_\mathrm{max}=2$")
ax[1].plot(data_12_hex[1:-2, 0], data_12_hex[1:-2, 2], label=r"$n_\mathrm{max}=3$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("hex_comp_n_alpha_0.pdf", dpi=200, bbox_inches='tight')

# %%
# comparison of lattices given n and alpha
# ###################################### FIG 1 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_1_square[1:-2, 0], data_1_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_1_tri[1:-2, 0], data_1_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_1_hex[1:-2, 0], data_1_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_1_square[1:-2, 0], data_1_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_1_tri[1:-2, 0], data_1_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_1_hex[1:-2, 0], data_1_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("lat_comp_n_1_alpha_0.1.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 10 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_10_square[1:-2, 0], data_10_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_10_tri[1:-2, 0], data_10_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_10_hex[1:-2, 0], data_10_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_10_square[1:-2, 0], data_10_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_10_tri[1:-2, 0], data_10_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_10_hex[1:-2, 0], data_10_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("lat_comp_n_1_alpha_0.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 11 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_11_square[1:-2, 0], data_11_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_11_tri[1:-2, 0], data_11_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_11_hex[1:-2, 0], data_11_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_11_square[1:-2, 0], data_11_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_11_tri[1:-2, 0], data_11_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_11_hex[1:-2, 0], data_11_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("lat_comp_n_2_alpha_0.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 12 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_12_square[1:-2, 0], data_12_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_12_tri[1:-2, 0], data_12_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_12_hex[1:-2, 0], data_12_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_12_square[1:-2, 0], data_12_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_12_tri[1:-2, 0], data_12_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_12_hex[1:-2, 0], data_12_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("lat_comp_n_3_alpha_0.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 2 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_2_square[1:-2, 0], data_2_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_2_tri[1:-2, 0], data_2_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_2_hex[1:-2, 0], data_2_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_2_square[1:-2, 0], data_2_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_2_tri[1:-2, 0], data_2_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_2_hex[1:-2, 0], data_2_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("lat_comp_n_1_alpha_0.01.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 3 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_7_square[1:-2, 0], data_7_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_7_tri[1:-2, 0], data_7_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_7_hex[1:-2, 0], data_7_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_7_square[1:-2, 0], data_7_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_7_tri[1:-2, 0], data_7_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_7_hex[1:-2, 0], data_7_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("lat_comp_n_1_alpha_0.001.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 4 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_3_square[1:-2, 0], data_3_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_3_tri[1:-2, 0], data_3_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_3_hex[1:-2, 0], data_3_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_3_square[1:-2, 0], data_3_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_3_tri[1:-2, 0], data_3_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_3_hex[1:-2, 0], data_3_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("lat_comp_n_2_alpha_0.1.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 5 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_4_square[1:-2, 0], data_4_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_4_tri[1:-2, 0], data_4_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_4_hex[1:-2, 0], data_4_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_4_square[1:-2, 0], data_4_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_4_tri[1:-2, 0], data_4_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_4_hex[1:-2, 0], data_4_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("lat_comp_n_2_alpha_0.01.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 6 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_8_square[1:-2, 0], data_8_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_8_tri[1:-2, 0], data_8_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_8_hex[1:-2, 0], data_8_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_8_square[1:-2, 0], data_8_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_8_tri[1:-2, 0], data_8_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_8_hex[1:-2, 0], data_8_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("lat_comp_n_2_alpha_0.001.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 7 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_5_square[1:-2, 0], data_5_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_5_tri[1:-2, 0], data_5_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_5_hex[1:-2, 0], data_5_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_5_square[1:-2, 0], data_5_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_5_tri[1:-2, 0], data_5_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_5_hex[1:-2, 0], data_5_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("lat_comp_n_3_alpha_0.1.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 8 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_6_square[1:-2, 0], data_6_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_6_tri[1:-2, 0], data_6_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_6_hex[1:-2, 0], data_6_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_6_square[1:-2, 0], data_6_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_6_tri[1:-2, 0], data_6_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_6_hex[1:-2, 0], data_6_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("lat_comp_n_3_alpha_0.01.pdf", dpi=200, bbox_inches='tight')

# ###################################### FIG 1 ################################################

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_9_square[1:-2, 0], data_9_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_9_tri[1:-2, 0], data_9_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_9_hex[1:-2, 0], data_9_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_9_square[1:-2, 0], data_9_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_9_tri[1:-2, 0], data_9_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_9_hex[1:-2, 0], data_9_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")

plt.savefig("lat_comp_n_3_alpha_0.001.pdf", dpi=200, bbox_inches='tight')

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(data_12_square[1:-2, 0], data_12_square[1:-2, 1], label=r"Sq.Lat.")
ax[0].plot(data_12_tri[1:-2, 0], data_12_tri[1:-2, 1], label=r"Tr.Lat.")
ax[0].plot(data_12_hex[1:-2, 0], data_12_hex[1:-2, 1], label=r"Hx.Lat.")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(data_12_square[1:-2, 0], data_12_square[1:-2, 2], label=r"Sq.Lat.")
ax[1].plot(data_12_tri[1:-2, 0], data_12_tri[1:-2, 2], label=r"Tr.Lat.")
ax[1].plot(data_12_hex[1:-2, 0], data_12_hex[1:-2, 2], label=r"Hx.Lat.")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")
plt.show()



def cross(ar, threshold):
    for i in range(len(ar)-1):
        if ar[i+1]-ar[i] > threshold:
            return i
    return len(ar)

tr = 0.06


al = [1, 2, 3]

t01 = np.power(1.01, cross(np.log10(data_12_square[1:-1, 1]), tr))
t001 = np.power(1.01, cross(np.log10(data_12_tri[1:-1, 1]), tr))
t0 = np.power(1.01, cross(np.log10(data_12_hex[1:-1, 1]), tr))


plt.plot(al, [t0, t01, t001], "o")
my_xticks = ['Square','Triangle','Hexagonal']
plt.xticks(al, my_xticks)
plt.xlabel(r"lattice type")
plt.ylabel(r"$\tau_1$")
plt.yscale("log")

# %%
# today I woke up and chose violence, hence I am doing this a very stupid way
# I will go for the structure [n_max, alpha] for each, hence they will be 3x4

def linear(x, a, b):
    return a*x + b

def cross(ar, threshold):
    x0 = ar[0]
    for i in range(len(ar)):
        if (ar[i] - x0) > tr:
            return i
    return len(ar)
    # res = 80
    # for i in range(0, len(ar)-res, res):
    #     t = np.array([1.01**i for i in range(res)])
    #     par = opt.curve_fit(linear, xdata=t, ydata=ar[i:i+res], p0=(0, 0))[0]
    #     if par[0] > threshold:
    #         return i
    # return nan


tr = 0.3


al = [1, 2, 3]

tri4 = np.genfromtxt("tri_number_alpha0.001_phi0.48_L100_4.txt", delimiter=" ")
tri5 = np.genfromtxt("tri_number_alpha0.001_phi0.49_L100_5.txt", delimiter=" ")
tri6 = np.genfromtxt("tri_number_alpha0.001_phi0.49_L100_6.txt", delimiter=" ")
tri7 = np.genfromtxt("tri_number_alpha0.001_phi0.49_L100_7.txt", delimiter=" ")
tri8 = np.genfromtxt("tri_number_alpha0.001_phi0.50_L100_8.txt", delimiter=" ")


t_ext = np.array([np.power(1.01, cross(np.log10(tri4[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tri5[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tri6[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tri7[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tri8[1:-2, 1]), tr))])

tri_dat = np.array([np.zeros(4) for i in range(3)])
squ_dat = np.array([np.zeros(4) for i in range(3)])
hex_dat = np.array([np.zeros(4) for i in range(3)])

tri_dat[0, 0] = np.power(1.01, cross(np.log10(data_10_tri[1:-2, 1]), tr))
tri_dat[0, 1] = np.power(1.01, cross(np.log10(data_7_tri[1:-2, 1]), tr))
tri_dat[0, 2] = np.power(1.01, cross(np.log10(data_2_tri[1:-2, 1]), tr))
tri_dat[0, 3] = np.power(1.01, cross(np.log10(data_1_tri[1:-2, 1]), tr))
tri_dat[1, 0] = np.power(1.01, cross(np.log10(data_11_tri[1:-2, 1]), tr))
tri_dat[1, 1] = np.power(1.01, cross(np.log10(data_8_tri[1:-2, 1]), tr))
tri_dat[1, 2] = np.power(1.01, cross(np.log10(data_4_tri[1:-2, 1]), tr))
tri_dat[1, 3] = np.power(1.01, cross(np.log10(data_3_tri[1:-2, 1]), tr))
tri_dat[2, 0] = np.power(1.01, cross(np.log10(data_12_tri[1:-2, 1]), tr))
tri_dat[2, 1] = np.power(1.01, cross(np.log10(data_9_tri[1:-2, 1]), tr))
tri_dat[2, 2] = np.power(1.01, cross(np.log10(data_6_tri[1:-2, 1]), tr))
tri_dat[2, 3] = np.power(1.01, cross(np.log10(data_5_tri[1:-2, 1]), tr))


squ_dat[0, 0] = np.power(1.01, cross(np.log10(data_10_square[1:-2, 1]), tr))
squ_dat[0, 1] = np.power(1.01, cross(np.log10(data_7_square[1:-2, 1]), tr))
squ_dat[0, 2] = np.power(1.01, cross(np.log10(data_2_square[1:-2, 1]), tr))
squ_dat[0, 3] = np.power(1.01, cross(np.log10(data_1_square[1:-2, 1]), tr))
squ_dat[1, 0] = np.power(1.01, cross(np.log10(data_11_square[1:-2, 1]), tr))
squ_dat[1, 1] = np.power(1.01, cross(np.log10(data_8_square[1:-2, 1]), tr))
squ_dat[1, 2] = np.power(1.01, cross(np.log10(data_4_square[1:-2, 1]), tr))
squ_dat[1, 3] = np.power(1.01, cross(np.log10(data_3_square[1:-2, 1]), tr))
squ_dat[2, 0] = np.power(1.01, cross(np.log10(data_12_square[1:-2, 1]), tr))
squ_dat[2, 1] = np.power(1.01, cross(np.log10(data_9_square[1:-2, 1]), tr))
squ_dat[2, 2] = np.power(1.01, cross(np.log10(data_6_square[1:-2, 1]), tr))
squ_dat[2, 3] = np.power(1.01, cross(np.log10(data_5_square[1:-2, 1]), tr))



hex_dat[0, 0] = np.power(1.01, cross(np.log10(data_10_hex[1:-2, 1]), tr))
hex_dat[0, 1] = np.power(1.01, cross(np.log10(data_7_hex[1:-2, 1]), tr))
hex_dat[0, 2] = np.power(1.01, cross(np.log10(data_2_hex[1:-2, 1]), tr))
hex_dat[0, 3] = np.power(1.01, cross(np.log10(data_1_hex[1:-2, 1]), tr))
hex_dat[1, 0] = np.power(1.01, cross(np.log10(data_11_hex[1:-2, 1]), tr))
hex_dat[1, 1] = np.power(1.01, cross(np.log10(data_8_hex[1:-2, 1]), tr))
hex_dat[1, 2] = np.power(1.01, cross(np.log10(data_4_hex[1:-2, 1]), tr))
hex_dat[1, 3] = np.power(1.01, cross(np.log10(data_3_hex[1:-2, 1]), tr))
hex_dat[2, 0] = np.power(1.01, cross(np.log10(data_12_hex[1:-2, 1]), tr))
hex_dat[2, 1] = np.power(1.01, cross(np.log10(data_9_hex[1:-2, 1]), tr))
hex_dat[2, 2] = np.power(1.01, cross(np.log10(data_6_hex[1:-2, 1]), tr))
hex_dat[2, 3] = np.power(1.01, cross(np.log10(data_5_hex[1:-2, 1]), tr))

# %%
plt.rcParams.update({'font.size': 30})


fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(24, 8))

labl=[r"$\alpha={0}$", r"$\alpha=10^{-3}$", r"$\alpha=10^{-2}$", r"$\alpha=10^{-1}$"]
nmax = [1, 2, 3]
nmax_ext = [4, 5, 6, 7, 8]
for i in range(3):
    ax[0].plot(nmax, tri_dat[:, i], label=labl[i])
    ax[1].plot(nmax, squ_dat[:, i], label=labl[i])
    ax[2].plot(nmax, hex_dat[:, i], label=labl[i])

ax[0].set_title("Triangle")
ax[1].set_title("Square")
ax[2].set_title("Hexagonal")

ax[0].legend()

ax[0].set_ylabel(r"$\tau_1$")
ax[0].set_xlabel(r"$n_\mathrm{max}$")
ax[1].set_xlabel(r"$n_\mathrm{max}$")
ax[2].set_xlabel(r"$n_\mathrm{max}$")

ax[0].set_yscale("log")
ax[1].set_yscale("log")
ax[2].set_yscale("log")
plt.savefig("tau_1_alpha_scaling.pdf", dpi=200, bbox_inches="tight")

plt.rcParams.update({'font.size': 18})

fig2 = plt.figure()
plt.plot(nmax_ext[:1], t_ext[:1], "ro")
plt.plot(nmax,tri_dat[:, 1], "ro")
plt.xlabel(r"$n_\mathrm{max}$")
plt.ylabel(r"$\tau_1$")
plt.yscale("log")
plt.grid()
plt.savefig("nmax_timescale.pdf", dpi=200, bbox_inches="tight")

fig3 = plt.figure()
plt.plot(nmax_ext[:1], np.log(t_ext[:1]), "ro")
plt.plot(nmax,np.log(tri_dat[:, 1]), "ro")
plt.xlabel(r"$n_\mathrm{max}$")
plt.ylabel(r"$\log{\tau_1}$")
plt.yscale("log")
plt.grid()
plt.savefig("nmax_timescale_log.pdf", dpi=200, bbox_inches="tight")

# %%
nrneighbours = [3, 4, 6]
plt.rcParams.update({'font.size': 14})

#array for alpha=0.001
n1 = [hex_dat[0, 1], squ_dat[0, 1], tri_dat[0, 1]]
n2 = [hex_dat[1, 1], squ_dat[1, 1], tri_dat[1, 1]]
n3 = [hex_dat[2, 1], squ_dat[2, 1], tri_dat[2, 1]]

plt.plot(nrneighbours, n1, "-o", label=r"$n_\mathrm{max}=1$")
plt.plot(nrneighbours, n2, "-o",  label=r"$n_\mathrm{max}=2$")
plt.plot(nrneighbours, n3, "-o",  label=r"$n_\mathrm{max}=3$")
plt.legend()
plt.yscale("log")
plt.grid()
plt.ylabel(r"$\tau_1$")
plt.xlabel("Number of directions")
plt.savefig("tau_1_lattice_type.pdf", dpi=200, bbox_inches="tight")

# %%
def dens(n, r, p, L):
    return (1 - (1 - r*p)**(1/n)) * n * L **2

pt = 0.5
ps = 0.59
ph = 0.69

r = 0.8
L = 100

print("Tri with n=4: %d, n=5: %d, n=6: %d, n=7: %d, n=8: %d, n=9: %d, n=10: %d" % (dens(4, r, pt, L), dens(5, r, pt, L), dens(6, r, pt, L), dens(7, r, pt, L), dens(8, r, pt, L), dens(9, r, pt, L), dens(10, r, pt, L)))
print("Squ with n=4: %d, n=5: %d, n=6: %d, n=7: %d, n=8: %d, n=9: %d, n=10: %d" % (dens(4, r, ps, L), dens(5, r, ps, L), dens(6, r, ps, L), dens(7, r, ps, L), dens(8, r, ps, L), dens(9, r, ps, L), dens(10, r, ps, L)))
print("Hex with n=4: %d, n=5: %d, n=6: %d, n=7: %d, n=8: %d, n=9: %d, n=10: %d" % (2*dens(4, r, ph, L), 2*dens(5, r, ph, L), 2*dens(6, r, ph, L), 2*dens(7, r, ph, L), 2*dens(8, r, ph, L), 2*dens(9, r, ph, L), 2*dens(10, r, ph, L)))
# Out:
# Tri with n=4: 4795, n=5: 4855, n=6: 4896, n=7: 4926, n=8: 4948, n=9: 4965, n=10: 4979
# Squ with n=4: 5902, n=5: 5995, n=6: 6058, n=7: 6103, n=8: 6138, n=9: 6165, n=10: 6186
# Hex with n=4: 14550, n=5: 14836, n=6: 15031, n=7: 15172, n=8: 15279, n=9: 15363, n=10: 15431

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(tri4[1:-2, 0], tri4[1:-2, 1], label=r"$n_\mathrm{max}=4$")
ax[0].plot(tri5[1:-2, 0], tri5[1:-2, 1], label=r"$n_\mathrm{max}=5$")
ax[0].plot(tri6[1:-2, 0], tri6[1:-2, 1], label=r"$n_\mathrm{max}=6$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(tri4[1:-2, 0], tri4[1:-2, 2], label=r"$n_\mathrm{max}=4$")
ax[1].plot(tri5[1:-2, 0], tri5[1:-2, 2], label=r"$n_\mathrm{max}=5$")
ax[1].plot(tri6[1:-2, 0], tri6[1:-2, 2], label=r"$n_\mathrm{max}=6$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")
plt.show()

# %%
# #################### density #######################

dens = [0.1, 0.2, 0.3, 0.4]

tr1 = np.genfromtxt("tri_number_alpha0.001_phi0.10_L100_1.txt", delimiter=" ")
tr2 = np.genfromtxt("tri_number_alpha0.001_phi0.20_L100_1.txt", delimiter=" ")
tr3 = np.genfromtxt("tri_number_alpha0.001_phi0.30_L100_1.txt", delimiter=" ")
tr4 = np.genfromtxt("tri_number_alpha0.001_phi0.40_L100_1.txt", delimiter=" ")

tri1 = np.array([np.power(1.01, cross(np.log10(tr1[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tr2[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tr3[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tr4[1:-2, 1]), tr))])


tr1 = np.genfromtxt("tri_number_alpha0.001_phi0.20_L100_2.txt", delimiter=" ")
tr2 = np.genfromtxt("tri_number_alpha0.001_phi0.40_L100_2.txt", delimiter=" ")
tr3 = np.genfromtxt("tri_number_alpha0.001_phi0.60_L100_2.txt", delimiter=" ")
tr4 = np.genfromtxt("tri_number_alpha0.001_phi0.80_L100_2.txt", delimiter=" ")

tri2 = np.array([np.power(1.01, cross(np.log10(tr1[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tr2[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tr3[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tr4[1:-2, 1]), tr))])


tr1 = np.genfromtxt("tri_number_alpha0.001_phi0.30_L100_3.txt", delimiter=" ")
tr2 = np.genfromtxt("tri_number_alpha0.001_phi0.60_L100_3.txt", delimiter=" ")
tr3 = np.genfromtxt("tri_number_alpha0.001_phi0.90_L100_3.txt", delimiter=" ")
tr4 = np.genfromtxt("tri_number_alpha0.001_phi1.20_L100_3.txt", delimiter=" ")
trperc = np.genfromtxt("tri_number_alpha0.001_phi0.47_L100_3.txt", delimiter=" ")

plt.rcParams.update({'font.size': 14})


fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(tr1[1:-2, 0], tr1[1:-2, 1], label=r"$\rho=0.1$")
ax[0].plot(tr2[1:-2, 0], tr2[1:-2, 1], label=r"$\rho=0.2$")
ax[0].plot(tr3[1:-2, 0], tr3[1:-2, 1], label=r"$\rho=0.3$")
ax[0].plot(tr4[1:-2, 0], tr4[1:-2, 1], label=r"$\rho=0.4$")
ax[0].plot(trperc[1:-2, 0], trperc[1:-2, 1], label=r"$\rho=0.8\rho_p \approx 0.15$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(tr1[1:-2, 0], tr1[1:-2, 2], label=r"$\rho=0.1$")
ax[1].plot(tr2[1:-2, 0], tr2[1:-2, 2], label=r"$\rho=0.2$")
ax[1].plot(tr3[1:-2, 0], tr3[1:-2, 2], label=r"$\rho=0.3$")
ax[1].plot(tr4[1:-2, 0], tr4[1:-2, 2], label=r"$\rho=0.4$")
ax[1].plot(trperc[1:-2, 0], trperc[1:-2, 2], label=r"$\rho=0.8\rho_p \approx 0.15$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
#ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")
plt.savefig("dens_transient_tri_001.pdf", dpi=200, bbox_inches="tight")

# %%
def cross2(ar, threshold):
    x0 = ar[0]
    for i in range(200, len(ar)):
        if (ar[i] - ar[i-200]) > tr:
            return i
    return len(ar)


tr = 0.1


tri3 = np.array([np.power(1.01, cross2(np.log10(tr1[1:-2, 1]), tr)), np.power(1.01, cross2(np.log10(tr2[1:-2, 1]), tr)), np.power(1.01, cross2(np.log10(tr3[1:-2, 1]), tr)), np.power(1.01, cross2(np.log10(tr4[1:-2, 1]), tr))])
fig1 = plt.figure()
plt.plot(dens, tri3)
plt.yscale("log")

for i in range(len(tri3)):
    print("tau_1 for rho=%.2f is %e" % (dens[i], tri3[i]))
# Out:
# tau_1 for rho=0.10 is 2.819804e+02
# tau_1 for rho=0.20 is 1.290010e+01
# tau_1 for rho=0.30 is 4.591623e+02
# tau_1 for rho=0.40 is 1.254368e+03

# %%
tr1 = np.genfromtxt("tri_number_alpha0.001_phi0.10_L100_1.txt", delimiter=" ")
tr2 = np.genfromtxt("tri_number_alpha0.001_phi0.20_L100_1.txt", delimiter=" ")
tr3 = np.genfromtxt("tri_number_alpha0.001_phi0.30_L100_1.txt", delimiter=" ")
tr4 = np.genfromtxt("tri_number_alpha0.001_phi0.40_L100_1.txt", delimiter=" ")
trperc = np.genfromtxt("tri_number_alpha0.001_phi0.40_L100_1.txt", delimiter=" ")


tri1 = np.array([np.power(1.01, cross(np.log10(tr1[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tr2[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tr3[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tr4[1:-2, 1]), tr))])




fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(tr1[1:-2, 0], tr1[1:-2, 1], label=r"$\rho=0.1$")
ax[0].plot(tr2[1:-2, 0], tr2[1:-2, 1], label=r"$\rho=0.2$")
ax[0].plot(tr3[1:-2, 0], tr3[1:-2, 1], label=r"$\rho=0.3$")
ax[0].plot(tr4[1:-2, 0], tr4[1:-2, 1], label=r"$\rho=0.4$")
ax[0].plot(trperc[1:-2, 0], trperc[1:-2, 1], label=r"$\rho=0.8\rho_p \approx 0.4$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(tr1[1:-2, 0], tr1[1:-2, 2], label=r"$\rho=0.1$")
ax[1].plot(tr2[1:-2, 0], tr2[1:-2, 2], label=r"$\rho=0.2$")
ax[1].plot(tr3[1:-2, 0], tr3[1:-2, 2], label=r"$\rho=0.3$")
ax[1].plot(tr4[1:-2, 0], tr4[1:-2, 2], label=r"$\rho=0.4$")
ax[1].plot(trperc[1:-2, 0], trperc[1:-2, 2], label=r"$\rho=0.8\rho_p \approx 0.4$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
#ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")
plt.savefig("dens_transient_tri_001_1.pdf", dpi=200, bbox_inches="tight")

# %%
tr1 = np.genfromtxt("tri_number_alpha0.001_phi0.20_L100_2.txt", delimiter=" ")
tr2 = np.genfromtxt("tri_number_alpha0.001_phi0.40_L100_2.txt", delimiter=" ")
tr3 = np.genfromtxt("tri_number_alpha0.001_phi0.60_L100_2.txt", delimiter=" ")
tr4 = np.genfromtxt("tri_number_alpha0.001_phi0.80_L100_2.txt", delimiter=" ")
trperc = np.genfromtxt("tri_number_alpha0.001_phi0.45_L100_2.txt", delimiter=" ")

tri2 = np.array([np.power(1.01, cross(np.log10(tr1[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tr2[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tr3[1:-2, 1]), tr)), np.power(1.01, cross(np.log10(tr4[1:-2, 1]), tr))])

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 8), sharex=True)
plt.tight_layout()

ax[0].plot(tr1[1:-2, 0], tr1[1:-2, 1], label=r"$\rho=0.1$")
ax[0].plot(tr2[1:-2, 0], tr2[1:-2, 1], label=r"$\rho=0.2$")
ax[0].plot(tr3[1:-2, 0], tr3[1:-2, 1], label=r"$\rho=0.3$")
ax[0].plot(tr4[1:-2, 0], tr4[1:-2, 1], label=r"$\rho=0.4$")
ax[0].plot(trperc[1:-2, 0], trperc[1:-2, 1], label=r"$\rho=0.8\rho_p \approx 0.23$")
ax[0].grid()
ax[0].set_yscale("log")
ax[0].legend()
ax[0].set_ylabel(r"$w_N$")
ax[0].set_xscale("log")

ax[1].plot(tr1[1:-2, 0], tr1[1:-2, 2], label=r"$\rho=0.1$")
ax[1].plot(tr2[1:-2, 0], tr2[1:-2, 2], label=r"$\rho=0.2$")
ax[1].plot(tr3[1:-2, 0], tr3[1:-2, 2], label=r"$\rho=0.3$")
ax[1].plot(tr4[1:-2, 0], tr4[1:-2, 2], label=r"$\rho=0.4$")
ax[1].plot(trperc[1:-2, 0], trperc[1:-2, 2], label=r"$\rho=0.8\rho_p \approx 0.23$")
ax[1].grid()
ax[1].set_yscale("log")
ax[1].set_xscale("log")
#ax[1].legend()
ax[1].set_ylabel("Mean cluster size")
ax[1].set_xlabel(r"Time $(t)$")
plt.savefig("dens_transient_tri_001_2.pdf", dpi=200, bbox_inches="tight")

print(np.shape(trperc))
# Out:
# (1390, 3)

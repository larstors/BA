# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as opt
import time
import random as rn
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
import matplotlib.patches as mpl_patches
from matplotlib import rcParams
from cmath import nan

plt.rcParams.update({'font.size': 16})

# %%
phi_10_1 = np.genfromtxt("tri_number_alpha0.001_phi0.10_L100_1.txt", delimiter=" ")
phi_10_2 = np.genfromtxt("tri_number_alpha0.001_phi0.20_L100_2.txt", delimiter=" ")
phi_10_3 = np.genfromtxt("tri_number_alpha0.001_phi0.30_L100_3.txt", delimiter=" ")
phi_10_4 = np.genfromtxt("tri_number_alpha0.001_phi0.40_L100_4.txt", delimiter=" ")
phi_20_1 = np.genfromtxt("tri_number_alpha0.001_phi0.20_L100_1.txt", delimiter=" ")
phi_20_2 = np.genfromtxt("tri_number_alpha0.001_phi0.40_L100_2.txt", delimiter=" ")
phi_20_3 = np.genfromtxt("tri_number_alpha0.001_phi0.60_L100_3.txt", delimiter=" ")
phi_20_4 = np.genfromtxt("tri_number_alpha0.001_phi0.80_L100_4.txt", delimiter=" ")
phi_30_1 = np.genfromtxt("tri_number_alpha0.001_phi0.30_L100_1.txt", delimiter=" ")
phi_30_2 = np.genfromtxt("tri_number_alpha0.001_phi0.60_L100_2.txt", delimiter=" ")
phi_30_3 = np.genfromtxt("tri_number_alpha0.001_phi0.90_L100_3.txt", delimiter=" ")
phi_30_4 = np.genfromtxt("tri_number_alpha0.001_phi1.20_L100_4.txt", delimiter=" ")
phi_40_1 = np.genfromtxt("tri_number_alpha0.001_phi0.40_L100_1.txt", delimiter=" ")
phi_40_2 = np.genfromtxt("tri_number_alpha0.001_phi0.80_L100_2.txt", delimiter=" ")
phi_40_3 = np.genfromtxt("tri_number_alpha0.001_phi1.20_L100_3.txt", delimiter=" ")
phi_40_4 = np.genfromtxt("tri_number_alpha0.001_phi1.60_L100_4.txt", delimiter=" ")
phi_50_1 = np.genfromtxt("tri_number_alpha0.001_phi0.50_L100_1.txt", delimiter=" ")
phi_50_2 = np.genfromtxt("tri_number_alpha0.001_phi1.00_L100_2.txt", delimiter=" ")
phi_50_3 = np.genfromtxt("tri_number_alpha0.001_phi1.50_L100_3.txt", delimiter=" ")
phi_50_4 = np.genfromtxt("tri_number_alpha0.001_phi2.00_L100_4.txt", delimiter=" ")

# %%
fig = plt.figure(figsize=(12, 5))

plt.plot(phi_10_1[:, 0], phi_10_1[:, 1], label=r"$n_\mathrm{max}=1$")
plt.plot(phi_10_2[:, 0], phi_10_2[:, 1], label=r"$n_\mathrm{max}=2$")
plt.plot(phi_10_3[:, 0], phi_10_3[:, 1], label=r"$n_\mathrm{max}=3$")
plt.plot(phi_10_4[:, 0], phi_10_4[:, 1], label=r"$n_\mathrm{max}=4$")

plt.xlabel(r"$t$")
plt.ylabel(r"$w_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $\rho = 0.1$")

plt.savefig("test_tri_ncomp_1.svg", dpi=500, bbox_inches="tight")

fig = plt.figure(figsize=(12, 6))

plt.plot(phi_20_1[:, 0], phi_20_1[:, 1], label=r"$n_\mathrm{max}=1$")
plt.plot(phi_20_2[:, 0], phi_20_2[:, 1], label=r"$n_\mathrm{max}=2$")
plt.plot(phi_20_3[:, 0], phi_20_3[:, 1], label=r"$n_\mathrm{max}=3$")
plt.plot(phi_20_4[:, 0], phi_20_4[:, 1], label=r"$n_\mathrm{max}=4$")

plt.xlabel(r"$t$")
plt.ylabel(r"$w_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $\rho = 0.2$")

fig = plt.figure(figsize=(12, 6))

plt.plot(phi_30_1[:, 0], phi_30_1[:, 1], label=r"$n_\mathrm{max}=1$")
plt.plot(phi_30_2[:, 0], phi_30_2[:, 1], label=r"$n_\mathrm{max}=2$")
plt.plot(phi_30_3[:, 0], phi_30_3[:, 1], label=r"$n_\mathrm{max}=3$")
plt.plot(phi_30_4[:, 0], phi_30_4[:, 1], label=r"$n_\mathrm{max}=4$")

plt.xlabel(r"$t$")
plt.ylabel(r"$w_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $\rho = 0.3$")

fig = plt.figure(figsize=(12, 6))

plt.plot(phi_40_1[:, 0], phi_40_1[:, 1], label=r"$n_\mathrm{max}=1$")
plt.plot(phi_40_2[:, 0], phi_40_2[:, 1], label=r"$n_\mathrm{max}=2$")
plt.plot(phi_40_3[:, 0], phi_40_3[:, 1], label=r"$n_\mathrm{max}=3$")
plt.plot(phi_40_4[:, 0], phi_40_4[:, 1], label=r"$n_\mathrm{max}=4$")

plt.xlabel(r"$t$")
plt.ylabel(r"$w_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $\rho = 0.4$")

fig = plt.figure(figsize=(12, 6))

plt.plot(phi_50_1[:, 0], phi_50_1[:, 1], label=r"$n_\mathrm{max}=1$")
plt.plot(phi_50_2[:, 0], phi_50_2[:, 1], label=r"$n_\mathrm{max}=2$")
plt.plot(phi_50_3[:, 0], phi_50_3[:, 1], label=r"$n_\mathrm{max}=3$")
plt.plot(phi_50_4[:, 0], phi_50_4[:, 1], label=r"$n_\mathrm{max}=4$")

plt.xlabel(r"$t$")
plt.ylabel(r"$w_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $\rho = 0.5$")
# Out:
# Text(0.5, 1.0, 'Triangular Lattice, $\\rho = 0.5$')

# %%
fig = plt.figure(figsize=(12, 6))

plt.plot(phi_10_1[:, 0], phi_10_1[:, 1], label=r"$\rho=0.1$")
plt.plot(phi_20_1[:, 0], phi_20_1[:, 1], label=r"$\rho=0.2$")
plt.plot(phi_30_1[:, 0], phi_30_1[:, 1], label=r"$\rho=0.3$")
plt.plot(phi_40_1[:, 0], phi_40_1[:, 1], label=r"$\rho=0.4$")
plt.plot(phi_50_1[:, 0], phi_50_1[:, 1], label=r"$\rho=0.5$")

plt.xlabel(r"$t$")
plt.ylabel(r"$w_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $n_\mathrm{max}=1$")

fig = plt.figure(figsize=(12, 6))

plt.plot(phi_10_2[:, 0], phi_10_2[:, 1], label=r"$\rho=0.1$")
plt.plot(phi_20_2[:, 0], phi_20_2[:, 1], label=r"$\rho=0.2$")
plt.plot(phi_30_2[:, 0], phi_30_2[:, 1], label=r"$\rho=0.3$")
plt.plot(phi_40_2[:, 0], phi_40_2[:, 1], label=r"$\rho=0.4$")
plt.plot(phi_50_2[:, 0], phi_50_2[:, 1], label=r"$\rho=0.5$")

plt.xlabel(r"$t$")
plt.ylabel(r"$w_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $n_\mathrm{max}=2$")

fig = plt.figure(figsize=(12, 6))

plt.plot(phi_10_3[:, 0], phi_10_3[:, 1], label=r"$\rho=0.1$")
plt.plot(phi_20_3[:, 0], phi_20_3[:, 1], label=r"$\rho=0.2$")
plt.plot(phi_30_3[:, 0], phi_30_3[:, 1], label=r"$\rho=0.3$")
plt.plot(phi_40_3[:, 0], phi_40_3[:, 1], label=r"$\rho=0.4$")
plt.plot(phi_50_3[:, 0], phi_50_3[:, 1], label=r"$\rho=0.5$")

plt.xlabel(r"$t$")
plt.ylabel(r"$w_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $n_\mathrm{max}=3$")

fig = plt.figure(figsize=(12, 6))

plt.plot(phi_10_4[:, 0], phi_10_4[:, 1], label=r"$\rho=0.1$")
plt.plot(phi_20_4[:, 0], phi_20_4[:, 1], label=r"$\rho=0.2$")
plt.plot(phi_30_4[:, 0], phi_30_4[:, 1], label=r"$\rho=0.3$")
plt.plot(phi_40_4[:, 0], phi_40_4[:, 1], label=r"$\rho=0.4$")
plt.plot(phi_50_4[:, 0], phi_50_4[:, 1], label=r"$\rho=0.5$")

plt.xlabel(r"$t$")
plt.ylabel(r"$w_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $n_\mathrm{max}=4$")
# Out:
# Text(0.5, 1.0, 'Triangular Lattice, $n_\\mathrm{max}=4$')

# %%
fig = plt.figure(figsize=(12, 6))

plt.plot(phi_10_1[:, 0], phi_10_1[:, 2], label=r"$n_\mathrm{max}=1$")
plt.plot(phi_10_2[:, 0], phi_10_2[:, 2], label=r"$n_\mathrm{max}=2$")
plt.plot(phi_10_3[:, 0], phi_10_3[:, 2], label=r"$n_\mathrm{max}=3$")
plt.plot(phi_10_4[:, 0], phi_10_4[:, 2], label=r"$n_\mathrm{max}=4$")

plt.xlabel(r"$t$")
plt.ylabel(r"$c_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $\rho = 0.1$")

fig = plt.figure(figsize=(12, 6))

plt.plot(phi_20_1[:, 0], phi_20_1[:, 2], label=r"$n_\mathrm{max}=1$")
plt.plot(phi_20_2[:, 0], phi_20_2[:, 2], label=r"$n_\mathrm{max}=2$")
plt.plot(phi_20_3[:, 0], phi_20_3[:, 2], label=r"$n_\mathrm{max}=3$")
plt.plot(phi_20_4[:, 0], phi_20_4[:, 2], label=r"$n_\mathrm{max}=4$")

plt.xlabel(r"$t$")
plt.ylabel(r"$c_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $\rho = 0.2$")

fig = plt.figure(figsize=(12, 6))

plt.plot(phi_30_1[:, 0], phi_30_1[:, 2], label=r"$n_\mathrm{max}=1$")
plt.plot(phi_30_2[:, 0], phi_30_2[:, 2], label=r"$n_\mathrm{max}=2$")
plt.plot(phi_30_3[:, 0], phi_30_3[:, 2], label=r"$n_\mathrm{max}=3$")
plt.plot(phi_30_4[:, 0], phi_30_4[:, 2], label=r"$n_\mathrm{max}=4$")

plt.xlabel(r"$t$")
plt.ylabel(r"$c_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $\rho = 0.3$")

fig = plt.figure(figsize=(12, 6))

plt.plot(phi_40_1[:, 0], phi_40_1[:, 2], label=r"$n_\mathrm{max}=1$")
plt.plot(phi_40_2[:, 0], phi_40_2[:, 2], label=r"$n_\mathrm{max}=2$")
plt.plot(phi_40_3[:, 0], phi_40_3[:, 2], label=r"$n_\mathrm{max}=3$")
plt.plot(phi_40_4[:, 0], phi_40_4[:, 2], label=r"$n_\mathrm{max}=4$")

plt.xlabel(r"$t$")
plt.ylabel(r"$c_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $\rho = 0.4$")

fig = plt.figure(figsize=(12, 6))

plt.plot(phi_50_1[:, 0], phi_50_1[:, 2], label=r"$n_\mathrm{max}=1$")
plt.plot(phi_50_2[:, 0], phi_50_2[:, 2], label=r"$n_\mathrm{max}=2$")
plt.plot(phi_50_3[:, 0], phi_50_3[:, 2], label=r"$n_\mathrm{max}=3$")
plt.plot(phi_50_4[:, 0], phi_50_4[:, 2], label=r"$n_\mathrm{max}=4$")

plt.xlabel(r"$t$")
plt.ylabel(r"$c_N$")

plt.yscale("log")
plt.xscale("log")

plt.legend()
plt.grid()

plt.title(r"Triangular Lattice, $\rho = 0.5$")
# Out:
# Text(0.5, 1.0, 'Triangular Lattice, $\\rho = 0.5$')

# %%
def detection(order: np.ndarray, K: int):
    kappa = 0
    for i in range(len(order) - K - 1):
        kappa = np.log10(order[i+K+1] / order[i])
        if kappa > 0.05:
            kappa = i
            break
    return i

# %%
upper_lim = 40


p101 = detection(phi_10_1[:, 1], upper_lim)
p201 = detection(phi_20_1[:, 1], upper_lim)
p301 = detection(phi_30_1[:, 1], upper_lim)
p401 = detection(phi_40_1[:, 1], upper_lim)
p501 = detection(phi_50_1[:, 1], upper_lim)

p102 = detection(phi_10_2[:, 1], upper_lim)
p202 = detection(phi_20_2[:, 1], upper_lim)
p302 = detection(phi_30_2[:, 1], upper_lim)
p402 = detection(phi_40_2[:, 1], upper_lim)
p502 = detection(phi_50_2[:, 1], upper_lim)

p103 = detection(phi_10_3[:, 1], upper_lim)
p203 = detection(phi_20_3[:, 1], upper_lim)
p303 = detection(phi_30_3[:, 1], upper_lim)
p403 = detection(phi_40_3[:, 1], upper_lim)
p503 = detection(phi_50_3[:, 1], upper_lim)

p104 = detection(phi_10_4[:, 1], upper_lim)
p204 = detection(phi_20_4[:, 1], upper_lim)
p304 = detection(phi_30_4[:, 1], upper_lim)
p404 = detection(phi_40_4[:, 1], upper_lim)
p504 = detection(phi_50_4[:, 1], upper_lim)

index = np.array([np.zeros(4) for i in range(5)])

index[0, 0] = p101
index[0, 1] = p102
index[0, 2] = p103
index[0, 3] = p104


index[1, 0] = p201
index[1, 1] = p202
index[1, 2] = p203
index[1, 3] = p204

index[2, 0] = p301
index[2, 1] = p302
index[2, 2] = p303
index[2, 3] = p304

index[3, 0] = p401
index[3, 1] = p402
index[3, 2] = p403
index[3, 3] = p404

index[4, 0] = p501
index[4, 1] = p502
index[4, 2] = p503
index[4, 3] = p504

print(index)
# Out:
# [[149. 369. 584. 463.]
#  [101. 121.   1. 771.]
#  [  0.   3. 423. 514.]
#  [ 15. 396. 478. 441.]
#  [  2. 407. 371. 403.]]
